# %% [markdown]
# <a href="https://colab.research.google.com/github/nzolotoff/labs-c/blob/main/report_for_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [10, 100, 1000, 10000, 100000]
y = [0.002375, 0.044708, 2.86742, 302.985, 32252.4]
fig, ax = plt.subplots ()
ax.plot (x,y, marker='o')
ax.set_title ('duration of bubblе sort')
ax.set_xlabel ("elements")
ax.set_ylabel ("time, ms")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x = [10, 100, 1000, 10000, 100000]

# %%
x = [10, 100, 1000, 10000, 100000]
y = [0.000291, 0.004916, 0.358167, 35.4753, 3459.56]
fig, ax = plt.subplots ()
ax.plot (x,y, marker='o')
ax.set_title ('duration of insertion sort')
ax.set_xlabel ("elements")
ax.set_ylabel ("time, ms")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x = [10, 100, 1000, 10000, 100000]
y = [0.000458, 0.01075, 0.703209, 65.8402, 6285.96]
fig, ax = plt.subplots ()
ax.plot (x,y, marker='o')
ax.set_title ('duration of selection sort')
ax.set_xlabel ("elements")
ax.set_ylabel ("time, ms")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
fig, ax = plt.subplots()
x = [10, 100, 1000, 10000, 100000]

y = [0.002375, 0.044708, 2.86742, 302.985, 32252.4]
ax.plot(x, y, marker='.', label='Bubble sort')

y = [0.000291, 0.004916, 0.358167, 35.4753, 3459.56]
ax.plot(x, y, marker='.', label='Insertion sort')

y = [0.000458, 0.01075, 0.703209, 65.8402, 6285.96]
ax.plot(x, y, marker='.', label='Selection sort')

plt.yscale("log")
plt.xscale("log")
ax.set_title('duration of all sorts')
ax.set_xlabel("number of elements")
ax.set_ylabel("time, ms")
ax.legend()

plt.show()
